# %%
import pandas as pd

# %%
fed_files = ["MORTGAGE30US.csv", "RRVRUSQ156N.csv", "CPIAUCSL.csv"]
dfs= [pd.read_csv(f, parse_dates=True, index_col=0) for f in fed_files]

# %%
dfs[0]
# Out:
#                   MORTGAGE30US
# observation_date
# 1971-04-02                7.33
# 1971-04-09                7.31
# 1971-04-16                7.31
# 1971-04-23                7.31
# 1971-04-30                7.29
# ...                        ...
# 2025-03-27                6.65
# 2025-04-03                6.64
# 2025-04-10                6.62
# 2025-04-17                6.83
# 2025-04-24                6.81
#
# [2822 rows x 1 columns]

# %%
fed_data = pd.concat(dfs, axis=1)
fed_data
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 1947-01-01                 NaN          NaN     21.48
# 1947-02-01                 NaN          NaN     21.62
# 1947-03-01                 NaN          NaN     22.00
# 1947-04-01                 NaN          NaN     22.00
# 1947-05-01                 NaN          NaN     21.95
# ...                        ...          ...       ...
# 2025-03-27                6.65          NaN       NaN
# 2025-04-03                6.64          NaN       NaN
# 2025-04-10                6.62          NaN       NaN
# 2025-04-17                6.83          NaN       NaN
# 2025-04-24                6.81          NaN       NaN
#
# [3675 rows x 3 columns]

# %%
# The forward fill method is used to fill in missing values in the DataFrame.
fed_data = fed_data.ffill()
fed_data
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 1947-01-01                 NaN          NaN    21.480
# 1947-02-01                 NaN          NaN    21.620
# 1947-03-01                 NaN          NaN    22.000
# 1947-04-01                 NaN          NaN    22.000
# 1947-05-01                 NaN          NaN    21.950
# ...                        ...          ...       ...
# 2025-03-27                6.65          6.9   319.615
# 2025-04-03                6.64          6.9   319.615
# 2025-04-10                6.62          6.9   319.615
# 2025-04-17                6.83          6.9   319.615
# 2025-04-24                6.81          6.9   319.615
#
# [3675 rows x 3 columns]

# %%
zillow_files = ["Metro_mlp_uc_sfrcondo_sm_week.csv", "Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv", ]
dfs = [pd.read_csv(f) for f in zillow_files]

# %%
dfs[0]
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-02-03  \
# 0      102001         0    United States    country       NaN    260950.0
# 1      394913         1     New York, NY        msa        NY    499250.0
# 2      753899         2  Los Angeles, CA        msa        CA    753875.0
# 3      394463         3      Chicago, IL        msa        IL    282325.0
# 4      394514         4       Dallas, TX        msa        TX    333923.0
# ..        ...       ...              ...        ...       ...         ...
# 923    753929       935       Zapata, TX        msa        TX         NaN
# 924    394743       936    Ketchikan, AK        msa        AK    290475.0
# 925    753874       937        Craig, CO        msa        CO    192125.0
# 926    395188       938       Vernon, TX        msa        TX         NaN
# 927    394767       939       Lamesa, TX        msa        TX         NaN
#
#      2018-02-10  2018-02-17  2018-02-24  2018-03-03  ...  2025-02-08  \
# 0      262225.0    264500.0    266975.0    268475.0  ...    390350.0
# 1      505750.0    510975.0    516195.0    522445.0  ...    746625.0
# 2      755125.0    757625.0    762000.0    769250.0  ...   1051000.0
# 3      285675.0    290450.0    294200.0    299200.0  ...    324675.0
# 4      336073.0    338175.0    340675.0    343200.0  ...    415283.0
# ..          ...         ...         ...         ...  ...         ...
# 923         NaN         NaN         NaN         NaN  ...    158000.0
# 924    290600.0    285725.0    279375.0    279425.0  ...    408500.0
# 925    191750.0    191475.0    190213.0    189700.0  ...    350950.0
# 926         NaN         NaN         NaN         NaN  ...    158625.0
# 927         NaN         NaN         NaN         NaN  ...    192249.0
#
#      2025-02-15  2025-02-22  2025-03-01  2025-03-08  2025-03-15  2025-03-22  \
# 0      391850.0    394000.0    396250.0    398100.0    399350.0    399725.0
# 1      749350.0    749575.0    749825.0    749950.0    752225.0    757000.0
# 2     1063500.0   1075000.0   1087250.0   1093475.0   1098475.0   1099725.0
# 3      325675.0    327150.0    328400.0    330925.0    333450.0    335975.0
# 4      415000.0    415000.0    415283.0    416508.0    418258.0         NaN
# ..          ...         ...         ...         ...         ...         ...
# 923    158000.0    158000.0    158000.0    158000.0    158000.0    158000.0
# 924    417000.0    420750.0    429250.0    437750.0    440250.0    442750.0
# 925    350838.0    350725.0    350725.0    350238.0    350850.0    353588.0
# 926    167625.0    174000.0    178750.0    182500.0    185000.0    184363.0
# 927    188749.0    185000.0    181000.0    184125.0    190125.0    195250.0
#
#      2025-03-29  2025-04-05  2025-04-12
# 0      402225.0    405750.0    409500.0
# 1      763250.0    769500.0    773500.0
# 2     1106225.0   1118500.0   1130750.0
# 3      338500.0    342000.0    344750.0
# 4      422975.0    425250.0    427250.0
# ..          ...         ...         ...
# 923    158000.0    158000.0    158000.0
# 924    445250.0    447750.0    447875.0
# 925    354850.0    355325.0    354938.0
# 926    185738.0    188238.0    190863.0
# 927    199250.0    199125.0    199125.0
#
# [928 rows x 381 columns]

# %%
# Filter for San Francisco, CA in each Zillow dataset
dfs = [df[df['RegionName'] == 'San Francisco, CA'] for df in dfs]

# Extract the date and price columns (skip metadata columns)
dfs = [pd.DataFrame(df.iloc[0, 5:]) for df in dfs]

# %%
dfs[1]
# Out:
#                         12
# 1996-02-29   207559.892448
# 1996-03-31   208043.354201
# 1996-04-30   208065.221875
# 1996-05-31   209222.807083
# 1996-06-30   210723.214199
# ...                    ...
# 2024-11-30  1158376.500929
# 2024-12-31  1153747.360456
# 2025-01-31  1147816.638132
# 2025-02-28  1153089.178763
# 2025-03-31  1163075.348071
#
# [350 rows x 1 columns]

# %%
for df in dfs:
    df.index = pd.to_datetime(df.index)
    df["month"] = df.index.to_period("M")
dfs[1]
# Out:
#                         12    month
# 1996-02-29   207559.892448  1996-02
# 1996-03-31   208043.354201  1996-03
# 1996-04-30   208065.221875  1996-04
# 1996-05-31   209222.807083  1996-05
# 1996-06-30   210723.214199  1996-06
# ...                    ...      ...
# 2024-11-30  1158376.500929  2024-11
# 2024-12-31  1153747.360456  2024-12
# 2025-01-31  1147816.638132  2025-01
# 2025-02-28  1153089.178763  2025-02
# 2025-03-31  1163075.348071  2025-03
#
# [350 rows x 2 columns]

# %%
# Step 1: Add 'month' column to fed_data (if not done already)
fed_data['month'] = fed_data.index.to_period('M')

# Step 2: Group FED data to monthly resolution (last value in each month)
fed_monthly = fed_data.groupby('month').last().reset_index()
fed_monthly['Date'] = fed_monthly['month'].dt.to_timestamp()
fed_monthly = fed_monthly.set_index('Date')

# Step 3: Merge with dfs[1] on 'month'
dfs[1]['month'] = dfs[1].index.to_period('M')
price_data = dfs[1].merge(fed_monthly, on='month', how='left')
price_data['Date'] = pd.to_datetime(price_data['month'].astype(str))
price_data = price_data.set_index('Date')

# drop 'month' column
price_data = price_data.drop(columns=['month'])

# Preview
print(price_data.head())
# Out:
#                        12  MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# Date
# 1996-02-01  207559.892448          7.32          7.9     155.0
# 1996-03-01  208043.354201          7.69          7.9     155.5
# 1996-04-01  208065.221875          7.92          7.8     156.1
# 1996-05-01  209222.807083          8.03          7.8     156.4
# 1996-06-01  210723.214199          8.29          7.8     156.7

# %%
price_data = price_data.rename(columns={12: 'value'})

price_data = price_data.rename(columns={
    '12': 'value',            # Zillow Value Index
    'MORTGAGE30US': 'interest',  # Mortgage Rate
    'RRVRUSQ156N': 'vacancy',    # Rental Vacancy
    'CPIAUCSL': 'cpi'            # Consumer Price Index
})
price_data
# Out:
#                      value  interest  vacancy      cpi
# Date
# 1996-02-01   207559.892448      7.32      7.9  155.000
# 1996-03-01   208043.354201      7.69      7.9  155.500
# 1996-04-01   208065.221875      7.92      7.8  156.100
# 1996-05-01   209222.807083      8.03      7.8  156.400
# 1996-06-01   210723.214199      8.29      7.8  156.700
# ...                    ...       ...      ...      ...
# 2024-11-01  1158376.500929      6.81      6.9  316.449
# 2024-12-01  1153747.360456      6.85      6.9  317.603
# 2025-01-01  1147816.638132      6.95      6.9  319.086
# 2025-02-01  1153089.178763      6.76      6.9  319.775
# 2025-03-01  1163075.348071      6.65      6.9  319.615
#
# [350 rows x 4 columns]

# %%
# Reindex fed_data to match all Zillow dates using forward fill
fed_data_aligned = fed_data.reindex(price_data.index, method='ffill')

# Merge without losing Zillow weekly resolution
price_data = price_data.join(fed_data_aligned, how='inner')

# Drop any remaining NaNs if any
price_data = price_data.dropna()

# Review the result
print(price_data.head(20))
price_data.tail(20)
# Out:
#                     value  interest  vacancy    cpi  MORTGAGE30US  \
# Date
# 1996-02-01  207559.892448      7.32      7.9  155.0          7.00
# 1996-03-01  208043.354201      7.69      7.9  155.5          7.41
# 1996-04-01  208065.221875      7.92      7.8  156.1          7.69
# 1996-05-01  209222.807083      8.03      7.8  156.4          7.92
# 1996-06-01  210723.214199      8.29      7.8  156.7          8.03
# 1996-07-01  212567.648924      8.19      8.0  157.0          8.29
# 1996-08-01  213502.045354      8.09      8.0  157.2          8.19
# 1996-09-01  213190.575776      8.16      8.0  157.7          8.09
# 1996-10-01  212708.567997      7.86      7.7  158.2          8.16
# 1996-11-01  211882.086921      7.52      7.7  158.7          7.78
# 1996-12-01  211278.096525      7.64      7.7  159.1          7.52
# 1997-01-01  211264.093856      7.88      7.5  159.4          7.64
# 1997-02-01  212232.744272      7.65      7.5  159.7          7.88
# 1997-03-01  214115.783857      7.97      7.5  159.8          7.65
# 1997-04-01  216210.280147      8.08      7.9  159.9          7.97
# 1997-05-01  219810.074609      7.94      7.9  159.9          8.08
# 1997-06-01  223198.012827      7.58      7.9  160.2          7.94
# 1997-07-01  227319.455598      7.43      7.9  160.4          7.58
# 1997-08-01  229474.624726      7.58      7.9  160.8          7.36
# 1997-09-01  230449.175928      7.28      7.9  161.2          7.58
#
#             RRVRUSQ156N  CPIAUCSL    month
# Date
# 1996-02-01          7.9     155.0  1996-02
# 1996-03-01          7.9     155.5  1996-03
# 1996-04-01          7.8     156.1  1996-04
# 1996-05-01          7.8     156.4  1996-05
# 1996-06-01          7.8     156.7  1996-06
# 1996-07-01          8.0     157.0  1996-07
# 1996-08-01          8.0     157.2  1996-08
# 1996-09-01          8.0     157.7  1996-09
# 1996-10-01          7.7     158.2  1996-10
# 1996-11-01          7.7     158.7  1996-11
# 1996-12-01          7.7     159.1  1996-12
# 1997-01-01          7.5     159.4  1997-01
# 1997-02-01          7.5     159.7  1997-02
# 1997-03-01          7.5     159.8  1997-03
# 1997-04-01          7.9     159.9  1997-04
# 1997-05-01          7.9     159.9  1997-05
# 1997-06-01          7.9     160.2  1997-06
# 1997-07-01          7.9     160.4  1997-07
# 1997-08-01          7.9     160.8  1997-08
# 1997-09-01          7.9     161.2  1997-09
#                      value  interest  vacancy      cpi  MORTGAGE30US  \
# Date
# 2023-08-01  1153263.991639      7.18      6.6  306.138          6.81
# 2023-09-01  1149300.444831      7.31      6.6  307.374          7.18
# 2023-10-01  1145239.148977      7.79      6.6  307.653          7.31
# 2023-11-01  1135511.751756      7.22      6.6  308.087          7.79
# 2023-12-01  1123910.029769      6.61      6.6  308.735          7.22
# 2024-01-01  1117219.094846      6.69      6.6  309.794          6.61
# 2024-02-01  1126486.089432      6.94      6.6  311.022          6.63
# 2024-03-01  1156819.972382      6.79      6.6  312.107          6.94
# 2024-04-01  1184749.969957      7.17      6.6  313.016          6.79
# 2024-05-01  1198100.898552      7.03      6.6  313.140          7.17
# 2024-06-01  1199250.094115      6.86      6.6  313.131          7.03
# 2024-07-01  1196278.657945      6.78      6.9  313.566          6.86
# 2024-08-01  1181126.544819      6.35      6.9  314.131          6.73
# 2024-09-01  1168545.886712      6.08      6.9  314.851          6.35
# 2024-10-01  1161303.390649      6.72      6.9  315.564          6.08
# 2024-11-01  1158376.500929      6.81      6.9  316.449          6.72
# 2024-12-01  1153747.360456      6.85      6.9  317.603          6.81
# 2025-01-01  1147816.638132      6.95      6.9  319.086          6.85
# 2025-02-01  1153089.178763      6.76      6.9  319.775          6.95
# 2025-03-01  1163075.348071      6.65      6.9  319.615          6.76
#
#             RRVRUSQ156N  CPIAUCSL    month
# Date
# 2023-08-01          6.6   306.138  2023-08
# 2023-09-01          6.6   307.374  2023-09
# 2023-10-01          6.6   307.653  2023-10
# 2023-11-01          6.6   308.087  2023-11
# 2023-12-01          6.6   308.735  2023-12
# 2024-01-01          6.6   309.794  2024-01
# 2024-02-01          6.6   311.022  2024-02
# 2024-03-01          6.6   312.107  2024-03
# 2024-04-01          6.6   313.016  2024-04
# 2024-05-01          6.6   313.140  2024-05
# 2024-06-01          6.6   313.131  2024-06
# 2024-07-01          6.9   313.566  2024-07
# 2024-08-01          6.9   314.131  2024-08
# 2024-09-01          6.9   314.851  2024-09
# 2024-10-01          6.9   315.564  2024-10
# 2024-11-01          6.9   316.449  2024-11
# 2024-12-01          6.9   317.603  2024-12
# 2025-01-01          6.9   319.086  2025-01
# 2025-02-01          6.9   319.775  2025-02
# 2025-03-01          6.9   319.615  2025-03

# %%
# Drop the duplicate original columns
price_data = price_data.drop(columns=['MORTGAGE30US', 'RRVRUSQ156N', 'CPIAUCSL'])
# Show the last 5 or 10 records to inspect recent data
print(price_data.tail(10))
# Out:
#                      value  interest  vacancy      cpi    month
# Date
# 2024-06-01  1199250.094115      6.86      6.6  313.131  2024-06
# 2024-07-01  1196278.657945      6.78      6.9  313.566  2024-07
# 2024-08-01  1181126.544819      6.35      6.9  314.131  2024-08
# 2024-09-01  1168545.886712      6.08      6.9  314.851  2024-09
# 2024-10-01  1161303.390649      6.72      6.9  315.564  2024-10
# 2024-11-01  1158376.500929      6.81      6.9  316.449  2024-11
# 2024-12-01  1153747.360456      6.85      6.9  317.603  2024-12
# 2025-01-01  1147816.638132      6.95      6.9  319.086  2025-01
# 2025-02-01  1153089.178763      6.76      6.9  319.775  2025-02
# 2025-03-01  1163075.348071      6.65      6.9  319.615  2025-03

# %%
print(price_data.describe())
# Out:
#          interest     vacancy         cpi
# count  350.000000  350.000000  350.000000
# mean     5.480114    8.172571  221.552094
# std      1.525473    1.431989   43.264575
# min      2.670000    5.600000  155.000000
# 25%      4.030000    6.900000  183.625000
# 50%      5.695000    8.000000  218.946500
# 75%      6.760000    9.600000  247.674750
# max      8.620000   11.100000  319.775000

# %%
price_data['real_value'] = price_data['value'] / price_data['cpi']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(price_data.index, price_data['value'], label='Nominal Value (USD)')

plt.title('San Francisco Home Value (1996-2025) (Monthly)')
plt.xlabel('Year')
plt.ylabel('Home Value (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Normalize prices to CPI base 100
price_data['adjusted_price'] = price_data['value'] / price_data['cpi'] * 100

# %%
price_data['adjusted_price'].plot(figsize=(12, 6), title="San Francisco Inflation-Adjusted Price (CPI Base 100)", grid=True)
plt.ylabel('Adjusted Price (Base CPI = 100)')
plt.show()

# %%
# Shift by 12 months (1 year later)
price_data["next_year"] = price_data["adjusted_price"].shift(-12)

price_data
# Out:
#                      value  interest  vacancy      cpi    month   real_value  \
# Date
# 1996-02-01   207559.892448      7.32      7.9  155.000  1996-02   1339.09608
# 1996-03-01   208043.354201      7.69      7.9  155.500  1996-03  1337.899384
# 1996-04-01   208065.221875      7.92      7.8  156.100  1996-04  1332.897001
# 1996-05-01   209222.807083      8.03      7.8  156.400  1996-05  1337.741733
# 1996-06-01   210723.214199      8.29      7.8  156.700  1996-06  1344.755675
# ...                    ...       ...      ...      ...      ...          ...
# 2024-11-01  1158376.500929      6.81      6.9  316.449  2024-11    3660.5472
# 2024-12-01  1153747.360456      6.85      6.9  317.603  2024-12  3632.671481
# 2025-01-01  1147816.638132      6.95      6.9  319.086  2025-01  3597.201501
# 2025-02-01  1153089.178763      6.76      6.9  319.775  2025-02   3605.93911
# 2025-03-01  1163075.348071      6.65      6.9  319.615  2025-03  3638.988621
#
#            adjusted_price      next_year
# Date
# 1996-02-01  133909.608031  132894.642625
# 1996-03-01  133789.938393  133989.852226
# 1996-04-01  133289.700112  135215.935051
# 1996-05-01  133774.173327  137467.213639
# 1996-06-01  134475.567453  139324.602264
# ...                   ...            ...
# 2024-11-01  366054.720012           None
# 2024-12-01  363267.148124           None
# 2025-01-01  359720.150095           None
# 2025-02-01  360593.910957           None
# 2025-03-01  363898.862091           None
#
# [350 rows x 8 columns]

# %%
price_data.dropna(inplace=True)
price_data
# Out:
#                      value  interest  vacancy      cpi    month   real_value  \
# Date
# 1996-02-01   207559.892448      7.32      7.9  155.000  1996-02   1339.09608
# 1996-03-01   208043.354201      7.69      7.9  155.500  1996-03  1337.899384
# 1996-04-01   208065.221875      7.92      7.8  156.100  1996-04  1332.897001
# 1996-05-01   209222.807083      8.03      7.8  156.400  1996-05  1337.741733
# 1996-06-01   210723.214199      8.29      7.8  156.700  1996-06  1344.755675
# ...                    ...       ...      ...      ...      ...          ...
# 2023-11-01  1135511.751756      7.22      6.6  308.087  2023-11   3685.68538
# 2023-12-01  1123910.029769      6.61      6.6  308.735  2023-12  3640.371289
# 2024-01-01  1117219.094846      6.69      6.6  309.794  2024-01  3606.329028
# 2024-02-01  1126486.089432      6.94      6.6  311.022  2024-02  3621.885556
# 2024-03-01  1156819.972382      6.79      6.6  312.107  2024-03  3706.485187
#
#            adjusted_price      next_year
# Date
# 1996-02-01  133909.608031  132894.642625
# 1996-03-01  133789.938393  133989.852226
# 1996-04-01  133289.700112  135215.935051
# 1996-05-01  133774.173327  137467.213639
# 1996-06-01  134475.567453  139324.602264
# ...                   ...            ...
# 2023-11-01  368568.538028  366054.720012
# 2023-12-01  364037.128855  363267.148124
# 2024-01-01  360632.902783  359720.150095
# 2024-02-01  362188.555611  360593.910957
# 2024-03-01  370648.518739  363898.862091
#
# [338 rows x 8 columns]

# %%
price_data["change"] = (price_data["next_year"] > price_data["adjusted_price"]).astype(int)
price_data
# Out:
#                      value  interest  vacancy      cpi    month   real_value  \
# Date
# 1996-02-01   207559.892448      7.32      7.9  155.000  1996-02   1339.09608
# 1996-03-01   208043.354201      7.69      7.9  155.500  1996-03  1337.899384
# 1996-04-01   208065.221875      7.92      7.8  156.100  1996-04  1332.897001
# 1996-05-01   209222.807083      8.03      7.8  156.400  1996-05  1337.741733
# 1996-06-01   210723.214199      8.29      7.8  156.700  1996-06  1344.755675
# ...                    ...       ...      ...      ...      ...          ...
# 2023-11-01  1135511.751756      7.22      6.6  308.087  2023-11   3685.68538
# 2023-12-01  1123910.029769      6.61      6.6  308.735  2023-12  3640.371289
# 2024-01-01  1117219.094846      6.69      6.6  309.794  2024-01  3606.329028
# 2024-02-01  1126486.089432      6.94      6.6  311.022  2024-02  3621.885556
# 2024-03-01  1156819.972382      6.79      6.6  312.107  2024-03  3706.485187
#
#            adjusted_price      next_year  change
# Date
# 1996-02-01  133909.608031  132894.642625       0
# 1996-03-01  133789.938393  133989.852226       1
# 1996-04-01  133289.700112  135215.935051       1
# 1996-05-01  133774.173327  137467.213639       1
# 1996-06-01  134475.567453  139324.602264       1
# ...                   ...            ...     ...
# 2023-11-01  368568.538028  366054.720012       0
# 2023-12-01  364037.128855  363267.148124       0
# 2024-01-01  360632.902783  359720.150095       0
# 2024-02-01  362188.555611  360593.910957       0
# 2024-03-01  370648.518739  363898.862091       0
#
# [338 rows x 9 columns]

# %%
print(price_data["change"].value_counts())
# Out:
# change
# 1    231
# 0    107
# Name: count, dtype: int64

# %%
# Separate the two classes
ups = price_data[price_data['change'] == 1]
downs = price_data[price_data['change'] == 0]

# Undersample the majority (ups) to match the minority (downs)
balanced_ups = ups.sample(n=len(downs), random_state=42)

# Combine them into a balanced dataset
balanced_price_data = pd.concat([balanced_ups, downs]).sort_index()

# Confirm balance
print(balanced_price_data['change'].value_counts())
# Out:
# change
# 0    107
# 1    107
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# 1. Select features and target
features = ['value', 'interest', 'vacancy', 'cpi', 'adjusted_price']
X = price_data[features]
y = price_data['change']

# 2. Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 4. K-Nearest Neighbors Model
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

print("\n=== K-Nearest Neighbors (KNN) ===")
print(classification_report(y_test, y_pred_knn))

# 5. Deep Learning Model (MLP)
mlp = MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500, random_state=42)
mlp.fit(X_train, y_train)
y_pred_mlp = mlp.predict(X_test)

print("\n=== Multi-Layer Perceptron (MLP - Deep Learning) ===")
print(classification_report(y_test, y_pred_mlp))
# Out:
# === K-Nearest Neighbors (KNN) ===
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        23
#            1       1.00      0.93      0.97        45
#
#     accuracy                           0.96        68
#    macro avg       0.94      0.97      0.95        68
# weighted avg       0.96      0.96      0.96        68
#
#
# === Multi-Layer Perceptron (MLP - Deep Learning) ===
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90        23
#            1       0.98      0.91      0.94        45
#
#     accuracy                           0.93        68
#    macro avg       0.91      0.93      0.92        68
# weighted avg       0.93      0.93      0.93        68
# c:\Sem_SJSU\cs171\cs171_2008\venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
